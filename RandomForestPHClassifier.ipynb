# %%
import numpy as np
import pandas as pd
from sklearn import tree

input_file = "ph_v1_days.csv"
df = pd.read_csv(input_file, header = 0)
df.dropna(subset =['Tea(black/green)'], how = 'all',inplace= True)

df.head()
# Out:
#            Date  PH_morning  PH_midday  PH_evening  PH_avg  Ailment  Gym  \
# 11   17.09.2017        6.26       6.21        5.36    5.94      NaN  NaN
# 17   23.09.2017        5.09       5.39        5.96    5.48      NaN  NaN
# 60   05.11.2017        6.28       6.24        6.12    6.21      NaN  NaN
# 121  05.01.2018        5.67       6.55        6.66    6.29      NaN  NaN
# 159  12.02.2018        5.66       6.68        6.76    6.37      NaN  NaN
#
#      Liquid  Lemon water  Tea(black/green)  ...  Cookie   Cake  Bun  \
# 11      900          0.0             250.0  ...     NaN    NaN  NaN
# 17     1550        250.0             300.0  ...    50.0  100.0  NaN
# 60     1800        250.0             500.0  ...     NaN  200.0  NaN
# 121    2200        250.0             250.0  ...     NaN  150.0  NaN
# 159    2800        300.0             450.0  ...     NaN    NaN  NaN
#
#      Croissant  Chocolate  Candies  Halva  Marshmallow  Red caviar  Jelly
# ...

# %%
df1 = df[['Liquid', 'Lemon water', 'Tea(black/green)', 'PH_avg' ]]

# %%
df1.head()
# Out:
#      Liquid  Lemon water  Tea(black/green)  PH_avg
# 11      900          0.0             250.0    5.94
# 17     1550        250.0             300.0    5.48
# 60     1800        250.0             500.0    6.21
# 121    2200        250.0             250.0    6.29
# 159    2800        300.0             450.0    6.37

# %%
df1.dropna(subset =['Lemon water'], how = 'all',inplace= True)
print(df1)
# Out:
#      Liquid  Lemon water  Tea(black/green)  PH_avg
# 11      900          0.0             250.0    5.94
# 17     1550        250.0             300.0    5.48
# 60     1800        250.0             500.0    6.21
# 121    2200        250.0             250.0    6.29
# 159    2800        300.0             450.0    6.37
# 168    2900        300.0             350.0    5.86
# 170    2625        300.0             400.0    5.89
# 172    3305        300.0             250.0    5.84
# 181    2550        300.0             500.0    5.39
# 183    2350        300.0             600.0    5.52
# 186    3050        300.0             450.0    5.81
# 188    2150        300.0             250.0    5.59
# 193    2875        300.0             300.0    5.40
# 196    2700        300.0             250.0    5.40
# 200    3000        300.0             550.0    5.35
# 201    2650        300.0             300.0    4.95
# 206    3195        300.0             250.0    5.49
# ...

# %%
df1.PH_avg = df1.PH_avg.astype(int)
# Out:
# 11     5
# 17     5
# 60     6
# 121    6
# 159    6
# 168    5
# 170    5
# 172    5
# 181    5
# 183    5
# 186    5
# 188    5
# 193    5
# 196    5
# 200    5
# 201    4
# 206    5
# 207    5
# 211    5
# Name: PH_avg, dtype: int64
# /Users/khrystynakopachevska/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
df1['Lemon water'] = df1['Lemon water'].astype(int)
df1['Tea(black/green)'] = df1['Tea(black/green)'].astype(int)

print(df1)
# Out:
#      Liquid  Lemon water  Tea(black/green)  PH_avg
# 11      900            0               250       5
# 17     1550          250               300       5
# 60     1800          250               500       6
# 121    2200          250               250       6
# 159    2800          300               450       6
# 168    2900          300               350       5
# 170    2625          300               400       5
# 172    3305          300               250       5
# 181    2550          300               500       5
# 183    2350          300               600       5
# 186    3050          300               450       5
# 188    2150          300               250       5
# 193    2875          300               300       5
# 196    2700          300               250       5
# 200    3000          300               550       5
# 201    2650          300               300       4
# 206    3195          300               250       5
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

features = list(df1.columns[:3])
features

y = df1['PH_avg']
X = df1[features]


clf = RandomForestClassifier(n_estimators=10)
clf = clf.fit(X, y)

# %%
print (clf.predict([[1000, 100, 300]]))
# Out:
# [5]
